# %%
import matplotlib.pyplot as plt
import quandl

data = quandl.get("WIKI/KO", start_date="2016-01-01", end_date="2018-01-01",
                  api_key="TrrV5dCZUX4fwAY1UyqU")
data.Close.plot()
plt.show()

# %%
quandl.ApiConfig.api_key = 'TrrV5dCZUX4fwAY1UyqU'
data1 = quandl.get('HKEX/83079', start_date='2010-02-20', end_date='2019-02-20')

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker 
import datetime as dt 
import matplotlib.dates as mdates

allstock = pd.read_csv('all_stocks_5yr.csv')
print(allstock.head())
